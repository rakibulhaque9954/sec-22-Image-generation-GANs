# %% [markdown]
# <a href="https://colab.research.google.com/github/rakibulhaque9954/sec-22-Image-generation-GANs/blob/main/Image_generation_GAN's_Anime_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # High Level Overview

# %% [markdown]
# ## Introdcution

# %% [markdown]
# 1. Generator: The generator's job is to create fake data, in this case, typically images. It starts with random noise as input and gradually learns to generate data that looks increasingly like real data. The generator tries to produce data that is indistinguishable from real data.
#
# 2. Discriminator: The discriminator's role is to distinguish between real data and fake data generated by the generator. It is essentially a binary classifier that is trained on real and fake examples. The discriminator learns to assign a high probability to real data and a low probability to fake data.
#
# The training process of a GAN involves a back-and-forth competition between the generator and discriminator:
#
# 1. Initially, the generator produces poor-quality fake data, and the discriminator can easily tell that it's fake. The discriminator provides feedback to the generator about the shortcomings of the generated data.
#
# 2. The generator uses this feedback to adjust its parameters (weights and biases) and improve the quality of its generated data. It aims to produce data that can better fool the discriminator.
#
# 3. Simultaneously, the discriminator also continues to improve its ability to distinguish real from fake data, as it receives more examples of both.
#
# 4. This adversarial training process continues iteratively until a certain convergence criterion is met. Ideally, the generator gets better at generating realistic data, and the discriminator gets better at distinguishing real from fake data.
#
# The ultimate goal is to reach a point where the generator generates data that is so realistic that the discriminator can no longer confidently distinguish it from real data. At this point, the GAN has reached a Nash equilibrium, and the generated data is considered highly convincing.
#
# GANs have been widely used in various applications, including image generation, style transfer, image-to-image translation, and more, thanks to their ability to generate realistic and high-quality data.
#
# ![Screenshot 2023-10-02 at 11.51.17.png](data:image/png;base64,...)

# %% [markdown]
# ## GAN Loss

# %% [markdown]
# 1. Initially, the generator's loss (G loss) is high because it's generating random noise, and the discriminator's loss (D loss) is low because it can easily distinguish real from fake.
#
# 2. As training progresses, the generator improves, and its loss decreases because it generates data that looks more like the real thing. Simultaneously, the discriminator gets better at its job, and its loss also decreases as it becomes more skilled at distinguishing real and fake data.
#
# 3. The training continues until a point where both losses converge to around 0.5. At this stage, the generator produces data that is so realistic that the discriminator can't reliably tell real from fake. This is the equilibrium you want to achieve in a GAN, where the generator creates high-quality data that closely resembles real data, and the discriminator is effectively guessing.
#
# This is the GAN's sweet spot, and we say it has reached a Nash equilibrium.
#
# Breakdown:
# - **Generator (G):** BCE loss for G aims to be lower because G wants to create synthetic data (images, in most cases) that is as close to real data as possible. From G's perspective, lower BCE loss means that the discriminator is having a harder time distinguishing its generated data from real data. So, G strives to minimize its loss to produce more convincing and realistic data.
#
# - **Discriminator (D):** On the other hand, BCE loss for D aims to be maximized (or its negative loss minimized) because D wants to become a better discriminator. Higher BCE loss from D's perspective means that it's having difficulty distinguishing real from fake data, which indicates that G is doing a better job at generating realistic data. So, D aims to maximize its loss by becoming more discerning.
#
# We have two BCE's for G and D both working Opposite direction as guided by the Optimizer.
#
# <h3>Optimized Loss Function Practice during Training:</h3>
# Let's break it down further:
#
# - In the early stages of training a GAN, the discriminator (D) can be too confident in its predictions. When using the standard BCE loss, if D is confident that a generated image is fake (assigns it a low probability close to 0), the loss can become saturated, and the gradients for the generator (G) can become extremely small. This means G may not receive strong feedback to improve its generated images.
#
# - To address this issue, a modification is sometimes made to the BCE loss for the generator. Instead of minimizing **`log(1 - D)`** (where `y` is 0 for fake data), it's maximized by minimizing **`-log(D)`** (where `y` is 1 for fake data). This effectively encourages the generator to generate data that has a higher probability of being considered real by the discriminator, especially in the early stages of training.
#
# - By maximizing **`log(D)`**, the generator receives a more informative gradient signal, even when D is confident that the generated data is fake. This encourages the generator to adjust its weights and biases to produce data that is less easily classified as fake by D, thus starting the learning process effectively.
#
# The Points above highlights the practical adjustments made during GAN training to ensure that the generator receives sufficient feedback early in training, helping it produce better-quality images and preventing D from being too confident too soon. This modification is a common practice in GAN training to improve stability and convergence. Flipping Labels, (real = fake : fake = real)
#
# One of the authors github has tips, here is the forked version: https://github.com/rakibulhaque9954/ganhacks

# %% [markdown]
# # Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Layer
from keras.layers import (Reshape,LeakyReLU,Dropout,Conv2DTranspose, Add, Conv2D, MaxPool2D, Dense,
                                     Flatten, InputLayer, BatchNormalization, Input, )
from keras.optimizers import Adam

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Kaggle Dataset Download

# %%
# !pip install -q kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d shanmukh05/anime-names-and-image-generation
# !unzip '/content/anime-names-and-image-generation.zip' -d '/content/dataset'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/dataset/dataset/Utena_Tenjou.jpg
#   inflating: /content/dataset/dataset/dataset/Utgarda_Garm.jpg
#   inflating: /content/dataset/dataset/dataset/Utopia_More.jpg
#   inflating: /content/dataset/dataset/dataset/Utsugi_Tsukimiya.jpg
#   inflating: /content/dataset/dataset/dataset/Utsuho_Azako.jpg
#   inflating: /content/dataset/dataset/dataset/Utsuho_Hasumi.jpg
#   inflating: /content/dataset/dataset/dataset/Utsuho_Nohotoke.jpg
#   inflating: /content/dataset/dataset/dataset/Utsuho_Reiuji.jpg
#   inflating: /content/dataset/dataset/dataset/Utsura_Nemuta.jpg
#   inflating: /content/dataset/dataset/dataset/Utsutsu_Hasegawa.jpg
#   inflating: /content/dataset/dataset/dataset/Utsutsu_Miya.jpg
#   inflating: /content/dataset/dataset/dataset/Utsutsuno_Jarno.jpg
#   inflating: /content/dataset/dataset/dataset/Utsuzo_Mashiroi.jpg
#   inflating: /content/dataset/dataset/dataset/Uwabami_Houjou.jpg
#   inflating: /content/dataset/dataset/dataset/Uzal_Delilah.jpg
#   inflating: /content/dataset/dataset/dataset/Uzannu_Uzatei.jpg
#   inflating: /content/dataset/dataset/dataset/Uzu_Kibune.jpg
#   inflating: /content/dataset/dataset/dataset/Uzu_Sanageyama.jpg
#   inflating: /content/dataset/dataset/dataset/Uzuki.jpg
#   inflating: /content/dataset/dataset/dataset/Uzuki_Hirokawa.jpg
#   inflating: /content/dataset/dataset/dataset/Uzuki_Ichihara.jpg
#   inflating: /content/dataset/dataset/dataset/Uzuki_Nakano.jpg
#   inflating: /content/dataset/dataset/dataset/Uzuki_Shimamura.jpg
#   inflating: /content/dataset/dataset/dataset/Uzuki_Shitenno.jpg
#   inflating: /content/dataset/dataset/dataset/Uzuki_Toreishi.jpg
#   inflating: /content/dataset/dataset/dataset/Uzuki_Yashiro.jpg
#   inflating: /content/dataset/dataset/dataset/Uzuki_Yusa.jpg
#   inflating: /content/dataset/dataset/dataset/Uzumaru_Mizunagi.jpg
#   inflating: /content/dataset/dataset/dataset/Uzume_Megusono.jpg
#   inflating: /content/dataset/dataset/dataset/Uzume_Tennouboshi.jpg
#   inflating: /content/dataset/dataset/dataset/Uzume_Uno.jpg
#   inflating: /content/dataset/dataset/dataset/Uzumi_Nara_Athha.jpg
#   inflating: /content/dataset/dataset/dataset/V_Juli_F.jpg
#   inflating: /content/dataset/dataset/dataset/V_Lila_F.jpg
#   inflating: /content/dataset/dataset/dataset/Vaclav_Havel.jpg
#   inflating: /content/dataset/dataset/dataset/Vago_Tassilo.jpg
#   inflating: /content/dataset/dataset/dataset/Vainney_Halter.jpg
#   inflating: /content/dataset/dataset/dataset/Valdred_Ivanhoe.jpg
#   inflating: /content/dataset/dataset/dataset/Valdrigr_Alsvieth.jpg
#   inflating: /content/dataset/dataset/dataset/Vale_Kimble.jpg
#   inflating: /content/dataset/dataset/dataset/Valencia_Tachibana.jpg
#   inflating: /content/dataset/dataset/dataset/Valentina_Glinka_Estes.jpg
#   inflating: /content/dataset/dataset/dataset/Valentine_Harpy.jpg
#   inflating: /content/dataset/dataset/dataset/Valentine_Villefort.jpg
#   inflating: /content/dataset/dataset/dataset/Valeria_Costacurta.jpg
#   inflating: /content/dataset/dataset/dataset/Valeria_Trifa.jpg
#   inflating: /content/dataset/dataset/dataset/Valeria_Vertone.jpg
#   inflating: /content/dataset/dataset/dataset/Valerian_Forest.jpg
#   inflating: /content/dataset/dataset/dataset/Valeriana_Foliery.jpg
#   inflating: /content/dataset/dataset/dataset/Valerio_Giacosa.jpg
#   inflating: /content/dataset/dataset/dataset/Valeriya_Kuou.jpg
#   inflating: /content/dataset/dataset/dataset/Valery_Ilyuchin.jpg
#   inflating: /content/dataset/dataset/dataset/Valery_Kaminsky.jpg
#   inflating: /content/dataset/dataset/dataset/Valik_Nigua.jpg
#   inflating: /content/dataset/dataset/dataset/Valkenhayn_R_Hellsing.jpg
#   inflating: /content/dataset/dataset/dataset/Valkus.jpg
#   inflating: /content/dataset/dataset/dataset/Valkyrie_Yuna.jpg
#   inflating: /content/dataset/dataset/dataset/Valsh_Rozzo_Valctovoel_Girika.jpg
#   inflating: /content/dataset/dataset/dataset/Valt_Aoi.jpg
#   inflating: /content/dataset/dataset/dataset/Valus_Lang.jpg
#   inflating: /content/dataset/dataset/dataset/Valvis_Lachloa.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Clief.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Dolform.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Fanel.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Flyheight.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Grants.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Hohenheim.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Kiryuuin.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Nocliff.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Reichnott.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Su_Choi.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Tenjuin.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Vat_Tran.jpg
#   inflating: /content/dataset/dataset/dataset/Van_Zant.jpg
#   inflating: /content/dataset/dataset/dataset/Van__Damme.jpg
#   inflating: /content/dataset/dataset/dataset/Vander_Hafiz.jpg
#   inflating: /content/dataset/dataset/dataset/Vanessa_Cromwell.jpg
#   inflating: /content/dataset/dataset/dataset/Vanessa_Diodati.jpg
#   inflating: /content/dataset/dataset/dataset/Vanessa_Enoteca.jpg
#   inflating: /content/dataset/dataset/dataset/Vanessa_Ibert.jpg
#   inflating: /content/dataset/dataset/dataset/Vanessa_Justine.jpg
#   inflating: /content/dataset/dataset/dataset/Vanessa_Laird.jpg
#   inflating: /content/dataset/dataset/dataset/Vanessa_Nightray.jpg
#   inflating: /content/dataset/dataset/dataset/Vanessa_ONeil.jpg
#   inflating: /content/dataset/dataset/dataset/Vanessa_Rene.jpg
#   inflating: /content/dataset/dataset/dataset/Vanessa_Walsh.jpg
#   inflating: /content/dataset/dataset/dataset/Vanfeny_Vamp.jpg
#   inflating: /content/dataset/dataset/dataset/Vanilla_H.jpg
#   inflating: /content/dataset/dataset/dataset/Vanilla_Ibu.jpg
#   inflating: /content/dataset/dataset/dataset/Vanilla_Ice.jpg
#   inflating: /content/dataset/dataset/dataset/Vanilla_Make_Repairs.jpg
#   inflating: /content/dataset/dataset/dataset/Vanilla_Mieux.jpg
#   inflating: /content/dataset/dataset/dataset/Vanilla_Peschutz.jpg
#   inflating: /content/dataset/dataset/dataset/Vanilla_The_Rabbit.jpg
#   inflating: /content/dataset/dataset/dataset/Vanilla_Vartla.jpg
#   inflating: /content/dataset/dataset/dataset/Vanir_Gullveig.jpg
#   inflating: /content/dataset/dataset/dataset/Vann_Flantyr.jpg
#   inflating: /content/dataset/dataset/dataset/Vanno_Clemente.jpg
#   inflating: /content/dataset/dataset/dataset/Vanze_Haldey.jpg
#   inflating: /content/dataset/dataset/dataset/Varchia_Ganasch.jpg
#   inflating: /content/dataset/dataset/dataset/Varel_Jin.jpg
#   inflating: /content/dataset/dataset/dataset/Vargas_Dyson.jpg
#   inflating: /content/dataset/dataset/dataset/Varie_Fanel.jpg
#   inflating: /content/dataset/dataset/dataset/Varys_Truss.jpg
#   inflating: /content/dataset/dataset/dataset/Vasco_Shot.jpg
#   inflating: /content/dataset/dataset/dataset/Vasilisa_Medvedeva.jpg
#   inflating: /content/dataset/dataset/dataset/Vasilisa_Yuryevna_Mostovaya.jpg
#   inflating: /content/dataset/dataset/dataset/Vasily_Nabokov.jpg
#   inflating: /content/dataset/dataset/dataset/Vassago_Casals.jpg
#   inflating: /content/dataset/dataset/dataset/Vato_Falman.jpg
#   inflating: /content/dataset/dataset/dataset/Vayne_Carudas_Solidor.jpg
#   inflating: /content/dataset/dataset/dataset/Vector_The_Crocodile.jpg
#   inflating: /content/dataset/dataset/dataset/Vedoba_Morte.jpg
#   inflating: /content/dataset/dataset/dataset/Veffidas_Feaze.jpg
#   inflating: /content/dataset/dataset/dataset/Vega_Victor.jpg
#   inflating: /content/dataset/dataset/dataset/Vegan_Eldriel.jpg
#   inflating: /content/dataset/dataset/dataset/Veigas_Terr.jpg
#   inflating: /content/dataset/dataset/dataset/Veldora_Tempest.jpg
#   inflating: /content/dataset/dataset/dataset/Velsaria_Eva_Fahrengart.jpg
#   inflating: /content/dataset/dataset/dataset/Veltol_Astrea.jpg
#   inflating: /content/dataset/dataset/dataset/Velved_WS_Rheinkymer.jpg
#   inflating: /content/dataset/dataset/dataset/Velvet_Crowe.jpg
#   inflating: /content/dataset/dataset/dataset/Ven_Uril.jpg
#   inflating: /content/dataset/dataset/dataset/Venelana_Gremory.jpg
#   inflating: /content/dataset/dataset/dataset/Veneo_Takashiro.jpg
#   inflating: /content/dataset/dataset/dataset/Venu_Gwak.jpg
#   inflating: /content/dataset/dataset/dataset/Venus_Kamiyama.jpg
#   inflating: /content/dataset/dataset/dataset/Vera_Collins.jpg
#   inflating: /content/dataset/dataset/dataset/Vera_Mist.jpg
#   inflating: /content/dataset/dataset/dataset/Vera_Ronstadt.jpg
#   inflating: /content/dataset/dataset/dataset/Vera_Zaharias.jpg
#   inflating: /content/dataset/dataset/dataset/Vera_del_Gnoni.jpg
#   inflating: /content/dataset/dataset/dataset/Verda_Kleiman.jpg
#   inflating: /content/dataset/dataset/dataset/Verde_Dogo_Alfentino.jpg
#   inflating: /content/dataset/dataset/dataset/Veresh_Aradar.jpg
#   inflating: /content/dataset/dataset/dataset/Verlaine_Bond.jpg
#   inflating: /content/dataset/dataset/dataset/Vermeer_Griffon.jpg
#   inflating: /content/dataset/dataset/dataset/Vermer_Reinhardt.jpg
#   inflating: /content/dataset/dataset/dataset/Veronica_Ananko.jpg
#   inflating: /content/dataset/dataset/dataset/Veronica_Boroswick.jpg
#   inflating: /content/dataset/dataset/dataset/Veronica_Kulikova.jpg
#   inflating: /content/dataset/dataset/dataset/Veronica_Lautreamont.jpg
#   inflating: /content/dataset/dataset/dataset/Veronica_Madaraki.jpg
#   inflating: /content/dataset/dataset/dataset/Veronica_Nasu.jpg
#   inflating: /content/dataset/dataset/dataset/Veronica_Rickenbacker.jpg
#   inflating: /content/dataset/dataset/dataset/Veronica_Thorne.jpg
#   inflating: /content/dataset/dataset/dataset/Veronica_de_Sade.jpg
#   inflating: /content/dataset/dataset/dataset/Verossa_Acous.jpg
#   inflating: /content/dataset/dataset/dataset/Vert_Far_Breton.jpg
#   inflating: /content/dataset/dataset/dataset/Vestemona_Lauren.jpg
#   inflating: /content/dataset/dataset/dataset/Vexille_Serra.jpg
#   inflating: /content/dataset/dataset/dataset/Via_Hibiki.jpg
#   inflating: /content/dataset/dataset/dataset/Viachufurav_da_Montewells.jpg
#   inflating: /content/dataset/dataset/dataset/Vice_Foreign_Minister_Darlian.jpg
#   inflating: /content/dataset/dataset/dataset/Vice_Granscenic.jpg
#   inflating: /content/dataset/dataset/dataset/Vice_Principal_Kometsuki.jpg
#   inflating: /content/dataset/dataset/dataset/Vice_principal_Nemoto.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Byron.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Clement_de_Girodelle.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_De_Corteau.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Delacroix.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Frankenstein.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Freeman.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Karel_Edinburgh.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Nikiforov.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Putin.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Talbot.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Tiger.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_Wolfman.jpg
#   inflating: /content/dataset/dataset/dataset/Victor_von_Grannzreich.jpg
#   inflating: /content/dataset/dataset/dataset/Victoria_Brownbase.jpg
#   inflating: /content/dataset/dataset/dataset/Victoria_Danglars.jpg
#   inflating: /content/dataset/dataset/dataset/Victoria_Terpsichore.jpg
#   inflating: /content/dataset/dataset/dataset/Victoria_Wood.jpg
#   inflating: /content/dataset/dataset/dataset/Victorique_de_Blois.jpg
#   inflating: /content/dataset/dataset/dataset/Victory_Ramenman.jpg
#   inflating: /content/dataset/dataset/dataset/Vidaldus_Taka.jpg
#   inflating: /content/dataset/dataset/dataset/Vidmenir_Knume.jpg
#   inflating: /content/dataset/dataset/dataset/Vier_von_Kleingelt.jpg
#   inflating: /content/dataset/dataset/dataset/Viggo_Kierkegaard.jpg
#   inflating: /content/dataset/dataset/dataset/Vignette_Tsukinose_April.jpg
#   inflating: /content/dataset/dataset/dataset/Viivi_Holopainen.jpg
#   inflating: /content/dataset/dataset/dataset/Vijeeter_Ecor.jpg
#   inflating: /content/dataset/dataset/dataset/Viktor_Izhmash.jpg
#   inflating: /content/dataset/dataset/dataset/Viktor_Ryazan.jpg
#   inflating: /content/dataset/dataset/dataset/Viktor_Zaharias.jpg
#   inflating: /content/dataset/dataset/dataset/Viktoriya_Ivanovna_Serebryakova.jpg
#   inflating: /content/dataset/dataset/dataset/Vilajulio_De_Metrio_Lu.jpg
#   inflating: /content/dataset/dataset/dataset/Vile_Roberto.jpg
#   inflating: /content/dataset/dataset/dataset/Vileena_Owell.jpg
#   inflating: /content/dataset/dataset/dataset/Viletta_Vadim.jpg
#   inflating: /content/dataset/dataset/dataset/Vilion_Drill_Heli.jpg
#   inflating: /content/dataset/dataset/dataset/Villar_Constance.jpg
#   inflating: /content/dataset/dataset/dataset/Villetta_Nu.jpg
#   inflating: /content/dataset/dataset/dataset/Vilma_Fachiri.jpg
#   inflating: /content/dataset/dataset/dataset/Vilma_Thorne.jpg
#   inflating: /content/dataset/dataset/dataset/Vince_Ingrado.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Alzey.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Bari.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Bold.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Dudley.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Jacintha.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Nightray.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Phantomhive.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Pike.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Rosenski.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Rune_Butler.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Valentine.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Vanetti.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Volaju.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_Vollachia.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_van_Gogh.jpg
#   inflating: /content/dataset/dataset/dataset/Vincent_van_Hossen.jpg
#   inflating: /content/dataset/dataset/dataset/Vindel_Mauser.jpg
#   inflating: /content/dataset/dataset/dataset/Vinegar_Doppio.jpg
#   inflating: /content/dataset/dataset/dataset/Vingt_Khushrenada.jpg
#   inflating: /content/dataset/dataset/dataset/Vinicius_Marky.jpg
#   inflating: /content/dataset/dataset/dataset/Vino_Dupre.jpg
#   inflating: /content/dataset/dataset/dataset/Vino_von_Lomzard.jpg
#   inflating: /content/dataset/dataset/dataset/Viola_Duplessis.jpg
#   inflating: /content/dataset/dataset/dataset/Viola_Gyune.jpg
#   inflating: /content/dataset/dataset/dataset/Violate_Behemoth.jpg
#   inflating: /content/dataset/dataset/dataset/Violen_Jiger.jpg
#   inflating: /content/dataset/dataset/dataset/Violet_Evergarden.jpg
#   inflating: /content/dataset/dataset/dataset/Violet_North.jpg
#   inflating: /content/dataset/dataset/dataset/Violet_Weinberg.jpg
#   inflating: /content/dataset/dataset/dataset/Violet_Witchy.jpg
#   inflating: /content/dataset/dataset/dataset/Violet_el_Bridget.jpg
#   inflating: /content/dataset/dataset/dataset/Violle_Amaretto.jpg
#   inflating: /content/dataset/dataset/dataset/Virgil_Fran.jpg
#   inflating: /content/dataset/dataset/dataset/Virgil_Walsh.jpg
#   inflating: /content/dataset/dataset/dataset/Virginia_Balance.jpg
#   inflating: /content/dataset/dataset/dataset/Virginia_Jones.jpg
#   inflating: /content/dataset/dataset/dataset/Virginia_Maxwell.jpg
#   inflating: /content/dataset/dataset/dataset/Virginia_Potts.jpg
#   inflating: /content/dataset/dataset/dataset/Virginia_Robertson.jpg
#   inflating: /content/dataset/dataset/dataset/Virosa_Amanita.jpg
#   inflating: /content/dataset/dataset/dataset/Virzoeve_Eclairover.jpg
#   inflating: /content/dataset/dataset/dataset/Viscount_Campbell.jpg
#   inflating: /content/dataset/dataset/dataset/Vishoub_Eleranka.jpg
#   inflating: /content/dataset/dataset/dataset/Vision_Icelus.jpg
#   inflating: /content/dataset/dataset/dataset/Visor_Crossroads.jpg
#   inflating: /content/dataset/dataset/dataset/Vitaly_Tinyanof.jpg
#   inflating: /content/dataset/dataset/dataset/Vitellius_Glamis.jpg
#   inflating: /content/dataset/dataset/dataset/Vittorio_Cataldi.jpg
#   inflating: /content/dataset/dataset/dataset/Vittorio_Conti.jpg
#   inflating: /content/dataset/dataset/dataset/Vittorio_Martini.jpg
#   inflating: /content/dataset/dataset/dataset/Vittorio_Mller.jpg
#   inflating: /content/dataset/dataset/dataset/Vittorio_Serevare.jpg
#   inflating: /content/dataset/dataset/dataset/Vittorio_de_Frescobaldi.jpg
#   inflating: /content/dataset/dataset/dataset/Vivi_Nefertari.jpg
#   inflating: /content/dataset/dataset/dataset/Vivi__Ornitier.jpg
#   inflating: /content/dataset/dataset/dataset/Vivian_Anseta.jpg
#   inflating: /content/dataset/dataset/dataset/Vivian_Jones.jpg
#   inflating: /content/dataset/dataset/dataset/Vivian_Justine.jpg
#   inflating: /content/dataset/dataset/dataset/Vivian_Melosa.jpg
#   inflating: /content/dataset/dataset/dataset/Vivian_Wong.jpg
#   inflating: /content/dataset/dataset/dataset/Viviane_Blanchard.jpg
#   inflating: /content/dataset/dataset/dataset/Viviano_Westwood.jpg
#   inflating: /content/dataset/dataset/dataset/Vivienne_Ootori.jpg
#   inflating: /content/dataset/dataset/dataset/Vizen_Bercourt.jpg
#   inflating: /content/dataset/dataset/dataset/Vlad_Tepes.jpg
#   inflating: /content/dataset/dataset/dataset/Vlad__Garfunkel.jpg
#   inflating: /content/dataset/dataset/dataset/Vladimir_Eliot_Kirilenko.jpg
#   inflating: /content/dataset/dataset/dataset/Vladimir_Ilyich_Popov.jpg
#   inflating: /content/dataset/dataset/dataset/Vladimir_Kocaqi.jpg
#   inflating: /content/dataset/dataset/dataset/Vladimir_Putin.jpg
#   inflating: /content/dataset/dataset/dataset/Vladislav_Grekov.jpg
#   inflating: /content/dataset/dataset/dataset/Vohu_Manah.jpg
#   inflating: /content/dataset/dataset/dataset/Volcott_OHuey.jpg
#   inflating: /content/dataset/dataset/dataset/Volk_Kahveci.jpg
#   inflating: /content/dataset/dataset/dataset/Volken_Macmani.jpg
#   inflating: /content/dataset/dataset/dataset/Volkov_Galosh.jpg
#   inflating: /content/dataset/dataset/dataset/Volkov_Vladimir.jpg
#   inflating: /content/dataset/dataset/dataset/Volrath_Fahren.jpg
#   inflating: /content/dataset/dataset/dataset/Von_Bitinghop_Irene.jpg
#   inflating: /content/dataset/dataset/dataset/Vossler_York_Azelas.jpg
#   inflating: /content/dataset/dataset/dataset/Vrlitwhai_Kridanik.jpg
#   inflating: /content/dataset/dataset/dataset/Vuelo_Eluko.jpg
#   inflating: /content/dataset/dataset/dataset/Vulcan_Haestus.jpg
#   inflating: /content/dataset/dataset/dataset/Vulcan_Joseph.jpg
#   inflating: /content/dataset/dataset/dataset/Vulcan_Markovic.jpg
#   inflating: /content/dataset/dataset/dataset/Vulgar_Hummer.jpg
#   inflating: /content/dataset/dataset/dataset/Wabisuke_Adenokouji.jpg
#   inflating: /content/dataset/dataset/dataset/Wabisuke_Jinnouchi.jpg
#   inflating: /content/dataset/dataset/dataset/Wac_Ericson.jpg
#   inflating: /content/dataset/dataset/dataset/Wada.jpg
#   inflating: /content/dataset/dataset/dataset/Wada_san.jpg
#   inflating: /content/dataset/dataset/dataset/Wade_Winston_Wilson.jpg
#   inflating: /content/dataset/dataset/dataset/Wafers_Charlotte.jpg
#   inflating: /content/dataset/dataset/dataset/Waglula_Hara.jpg
#   inflating: /content/dataset/dataset/dataset/Wagner.jpg
#   inflating: /content/dataset/dataset/dataset/Wahanly_Shume.jpg
#   inflating: /content/dataset/dataset/dataset/Wahl_Icht.jpg
#   inflating: /content/dataset/dataset/dataset/Waichirou_Sekiya.jpg
#   inflating: /content/dataset/dataset/dataset/Wajima.jpg
#   inflating: /content/dataset/dataset/dataset/Waka_Asachi.jpg
#   inflating: /content/dataset/dataset/dataset/Waka_Inoue.jpg
#   inflating: /content/dataset/dataset/dataset/Waka_Karasuma.jpg
#   inflating: /content/dataset/dataset/dataset/Waka_Kisaki.jpg
#   inflating: /content/dataset/dataset/dataset/Waka_Mizuki.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Anzai.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Fujieda.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Fujimiya.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Hano.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Harukaze.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Himeji.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Ichinose.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Kaburaki.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Katagiri.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Kawasumi.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Kohashi.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Kusakabe.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Kusuka.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Kutsuki.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Kuze.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Mine.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Nogi.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Otowa.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Saegusa.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Satsukimidori.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Shinohara.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Takachiho.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Tsukishima.jpg
#   inflating: /content/dataset/dataset/dataset/Wakaba_Yuki.jpg
#   inflating: /content/dataset/dataset/dataset/Wakae_Toda.jpg
#   inflating: /content/dataset/dataset/dataset/Wakako_Konohana.jpg
#   inflating: /content/dataset/dataset/dataset/Wakako_Murasaki.jpg
#   inflating: /content/dataset/dataset/dataset/Wakako_Usami.jpg
#   inflating: /content/dataset/dataset/dataset/Wakako_Yoshimi.jpg
#   inflating: /content/dataset/dataset/dataset/Wakame_Isono.jpg
#   inflating: /content/dataset/dataset/dataset/Wakamoto.jpg
#   inflating: /content/dataset/dataset/dataset/Wakamoto_Hara_Itaminokami.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Abe_no.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Aotsuki.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Endou.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Esono.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Gojou.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Higasayama.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Hirata.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Houjou.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Itou.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Katayama.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Koda.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Komochi.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Kuzumi.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Manabe.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Misaki.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Morizono.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Mutou.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Nakatani.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Nanamiya.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Narita.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Nura.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Sakai.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Sakoi.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Sakurai.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Sawamura.jpg
#   inflating: /content/dataset/dataset/dataset/Wakana_Wakatsuki.jpg
#   inflating: /content/dataset/dataset/dataset/Wakanosuke_Handou.jpg
#   inflating: /content/dataset/dataset/dataset/Wakasa_Ayabe.jpg
#   inflating: /content/dataset/dataset/dataset/Wakasa_Jyujo.jpg
#   inflating: /content/dataset/dataset/dataset/Wakasa_Kusu.jpg
#   inflating: /content/dataset/dataset/dataset/Wakashi_Hiyoshi.jpg
#   inflating: /content/dataset/dataset/dataset/Wakatake_Janome.jpg
#   inflating: /content/dataset/dataset/dataset/Wakatoshi_Ushijima.jpg
#   inflating: /content/dataset/dataset/dataset/Wakatsuki.jpg
#   inflating: /content/dataset/dataset/dataset/Wakatsuki_Ran.jpg
#   inflating: /content/dataset/dataset/dataset/Wakatsuki_Takeshi.jpg
#   inflating: /content/dataset/dataset/dataset/Waki_Yoshiwara.jpg
#   inflating: /content/dataset/dataset/dataset/Wakisaka.jpg
#   inflating: /content/dataset/dataset/dataset/Wakiya_Komurasaki.jpg
#   inflating: /content/dataset/dataset/dataset/Wako_Agemaki.jpg
#   inflating: /content/dataset/dataset/dataset/Waku_Konuma.jpg
#   inflating: /content/dataset/dataset/dataset/Wakui.jpg
#   inflating: /content/dataset/dataset/dataset/Wald_Richter.jpg
#   inflating: /content/dataset/dataset/dataset/Wales_Tudor.jpg
#   inflating: /content/dataset/dataset/dataset/Waletta_Codrington.jpg
#   inflating: /content/dataset/dataset/dataset/Walker_Yumasaki.jpg
#   inflating: /content/dataset/dataset/dataset/Wallace_Warwick.jpg
#   inflating: /content/dataset/dataset/dataset/Wally_Buchanan.jpg
#   inflating: /content/dataset/dataset/dataset/Walnut_Kang.jpg
#   inflating: /content/dataset/dataset/dataset/Walt_Bedd.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_C_Dornez.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_Evans.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_Gates.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_Henderson.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_Hewitt.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_Islands.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_Jack.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_Malkin.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_Mountain.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_Raleigh.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_Walzac.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_de_la_Poer_Straid.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_von_Haizerad.jpg
#   inflating: /content/dataset/dataset/dataset/Walter_von_Schnkopf.jpg
#   inflating: /content/dataset/dataset/dataset/Walther_Krger.jpg
#   inflating: /content/dataset/dataset/dataset/Waltorana_von_Bielefeld.jpg
#   inflating: /content/dataset/dataset/dataset/Waltrud_Krupinski.jpg
#   inflating: /content/dataset/dataset/dataset/Wan_Chen.jpg
#   inflating: /content/dataset/dataset/dataset/Wan_Derbard.jpg
#   inflating: /content/dataset/dataset/dataset/Wanderlei_Zillminnko.jpg
#   inflating: /content/dataset/dataset/dataset/Wang.jpg
#   inflating: /content/dataset/dataset/dataset/Wang_Chan.jpg
#   inflating: /content/dataset/dataset/dataset/Wang_Ja_Rim.jpg
#   inflating: /content/dataset/dataset/dataset/Wang_Jin.jpg
#   inflating: /content/dataset/dataset/dataset/Wang_Jun.jpg
#   inflating: /content/dataset/dataset/dataset/Wang_Yang.jpg
#   inflating: /content/dataset/dataset/dataset/Wang_Zhao.jpg
#   inflating: /content/dataset/dataset/dataset/Wang_Zixuan.jpg
#   inflating: /content/dataset/dataset/dataset/Wangji_Lan.jpg
#   inflating: /content/dataset/dataset/dataset/Wangnan_Ja.jpg
#   inflating: /content/dataset/dataset/dataset/Wanibuchi.jpg
#   inflating: /content/dataset/dataset/dataset/Wanyin_Jiang.jpg
#   inflating: /content/dataset/dataset/dataset/Wao_Sakurai.jpg
#   inflating: /content/dataset/dataset/dataset/Waon_Nishijima.jpg
#   inflating: /content/dataset/dataset/dataset/Warabi_Hanasaka.jpg
#   inflating: /content/dataset/dataset/dataset/Warera_Nantes.jpg
#   inflating: /content/dataset/dataset/dataset/Wario_Hashida.jpg
#   inflating: /content/dataset/dataset/dataset/Warren_Grantz.jpg
#   inflating: /content/dataset/dataset/dataset/Warren_Hughes.jpg
#   inflating: /content/dataset/dataset/dataset/Warren_Rocko.jpg
#   inflating: /content/dataset/dataset/dataset/Warren_Trace.jpg
#   inflating: /content/dataset/dataset/dataset/Warrius_Zero.jpg
#   inflating: /content/dataset/dataset/dataset/Warrod_Sequen.jpg
#   inflating: /content/dataset/dataset/dataset/Wasabi_Izuno.jpg
#   inflating: /content/dataset/dataset/dataset/Wasabi_Kawamura.jpg
#   inflating: /content/dataset/dataset/dataset/Washibana.jpg
#   inflating: /content/dataset/dataset/dataset/Washiho_Usuki.jpg
#   inflating: /content/dataset/dataset/dataset/Washizu_Takateru.jpg
#   inflating: /content/dataset/dataset/dataset/Washu_Kozuka.jpg
#   inflating: /content/dataset/dataset/dataset/Washuu_Hakubi.jpg
#   inflating: /content/dataset/dataset/dataset/Wasuke_Konishi.jpg
#   inflating: /content/dataset/dataset/dataset/Watame_Tsunomaki.jpg
#   inflating: /content/dataset/dataset/dataset/Watanabe.jpg
#   inflating: /content/dataset/dataset/dataset/Watanabe_Ken.jpg
#   inflating: /content/dataset/dataset/dataset/Watanabe_Tanaka_.jpg
#   inflating: /content/dataset/dataset/dataset/Watanuki.jpg
#   inflating: /content/dataset/dataset/dataset/Watarai.jpg
#   inflating: /content/dataset/dataset/dataset/Watari_Mochizuki.jpg
#   inflating: /content/dataset/dataset/dataset/Watari_Yutaka.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Aihara.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Aikawa.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Akiyama.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Amachi.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Amami.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Amanogawa.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Asahina.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Azuma.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Date.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Fujii.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Furuya.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Harue.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Henmi.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Hibiki.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Himeji.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Hoshino.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Ikusabe.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Imagase.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Ishigami.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Itabashi.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Iwano.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Jouichi.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kagami.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kaidou.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kaneda.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kannazuki.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kanou.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kariba.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Katsumoto.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kawanishi.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kijima.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kitayama.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kubo.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kuon.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Kurozuma.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Manseibashi.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Maruyama.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Matoba.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Minakami.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Mitani.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Mizoguchi.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Mochizuki.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Morinaka.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Morokado.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Nakabayashi.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Narusawa.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Nireasaki.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Onaga.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Ootake.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Ootori.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Ozawa.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Sanzu.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Shimoto.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Tachibana.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Takagi.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Takamura.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Toda.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Tokitou.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Toudou.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Urazoe.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Yamada.jpg
#   inflating: /content/dataset/dataset/dataset/Wataru_Yuuki.jpg
#   inflating: /content/dataset/dataset/dataset/Watase_Kasasagi.jpg
#   inflating: /content/dataset/dataset/dataset/Watayuki_Amatsuka.jpg
#   inflating: /content/dataset/dataset/dataset/Watkins.jpg
#   inflating: /content/dataset/dataset/dataset/Wato_Chiyoko.jpg
#   inflating: /content/dataset/dataset/dataset/Waver_Velvet.jpg
#   inflating: /content/dataset/dataset/dataset/Wayasu_Dokugasu.jpg
#   inflating: /content/dataset/dataset/dataset/Wayne_Eisner.jpg
#   inflating: /content/dataset/dataset/dataset/Wayne_Uedera.jpg
#   inflating: /content/dataset/dataset/dataset/Wayne__King.jpg
#   inflating: /content/dataset/dataset/dataset/Weather_Report.jpg
#   inflating: /content/dataset/dataset/dataset/Wedge_Antilles.jpg
#   inflating: /content/dataset/dataset/dataset/Weedon_Scott.jpg
#   inflating: /content/dataset/dataset/dataset/Weevil_Edward.jpg
#   inflating: /content/dataset/dataset/dataset/Wei_Fei_Li.jpg
#   inflating: /content/dataset/dataset/dataset/Wei_Gao.jpg
#   inflating: /content/dataset/dataset/dataset/Wei_Pang.jpg
#   inflating: /content/dataset/dataset/dataset/Wei_Wang.jpg
#   inflating: /content/dataset/dataset/dataset/Wei_Yong_Qian.jpg
#   inflating: /content/dataset/dataset/dataset/Wein_Cruz.jpg
#   inflating: /content/dataset/dataset/dataset/Weiss_Edge.jpg
#   inflating: /content/dataset/dataset/dataset/Weiss_Schnee.jpg
#   inflating: /content/dataset/dataset/dataset/Welch_Vineyard.jpg
#   inflating: /content/dataset/dataset/dataset/Weldeschtein__Krom_Raggs.jpg
#   inflating: /content/dataset/dataset/dataset/Welf_Crozzo.jpg
#   inflating: /content/dataset/dataset/dataset/Welkin_Gunther.jpg
#   inflating: /content/dataset/dataset/dataset/Welte_Talan.jpg
#   inflating: /content/dataset/dataset/dataset/Wen_Yong_Fa.jpg
#   inflating: /content/dataset/dataset/dataset/Wen_li_Yang.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Earhart.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Garret.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Hertz.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Marvell.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_McCole.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Moira_Angela_Darling.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Mos.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Nablesse.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Ryan.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Ryder.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Velvet.jpg
#   inflating: /content/dataset/dataset/dataset/Wendy_Vou_Umbrella.jpg
#   inflating: /content/dataset/dataset/dataset/Wenge_Kong.jpg
#   inflating: /content/dataset/dataset/dataset/Wenqing_Han.jpg
#   inflating: /content/dataset/dataset/dataset/Wentzel_Ahbe.jpg
#   inflating: /content/dataset/dataset/dataset/Wentzel_von_Hasselback.jpg
#   inflating: /content/dataset/dataset/dataset/Wenzhou_Yu.jpg
#   inflating: /content/dataset/dataset/dataset/Werner_Maxwell.jpg
#   inflating: /content/dataset/dataset/dataset/Werner__von_Trapp.jpg
#   inflating: /content/dataset/dataset/dataset/Wes_Evans.jpg
#   inflating: /content/dataset/dataset/dataset/Wesley_Grant.jpg
#   inflating: /content/dataset/dataset/dataset/Westia_Chartreux.jpg
#   inflating: /content/dataset/dataset/dataset/Wezmar_Diorg.jpg
#   inflating: /content/dataset/dataset/dataset/Whie_Young_Jang.jpg
#   inflating: /content/dataset/dataset/dataset/White_Bomber.jpg
#   inflating: /content/dataset/dataset/dataset/White_Cloud.jpg
#   inflating: /content/dataset/dataset/dataset/White_Gamba_Ranger.jpg
#   inflating: /content/dataset/dataset/dataset/White_Taki.jpg
#   inflating: /content/dataset/dataset/dataset/White__Rabbit.jpg
#   inflating: /content/dataset/dataset/dataset/Whitney_Hagas_Matsumoto.jpg
#   inflating: /content/dataset/dataset/dataset/Widge_Burns.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Ebara.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Endou.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Hagoromo.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Hayase.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Hayashi.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Kobayashi.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Koizumi.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Kurokawa.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Nagata.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Sant.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Shibazaki.jpg
#   inflating: /content/dataset/dataset/dataset/Wife_Utamura.jpg
#   inflating: /content/dataset/dataset/dataset/Wiggins.jpg
#   inflating: /content/dataset/dataset/dataset/Wilbell_voll_Erslied.jpg
#   inflating: /content/dataset/dataset/dataset/Wilber_Millbill.jpg
#   inflating: /content/dataset/dataset/dataset/Wilbur_Danclaude.jpg
#   inflating: /content/dataset/dataset/dataset/Wilbur_Whateley.jpg
#   inflating: /content/dataset/dataset/dataset/Wilfred_Anderson.jpg
#   inflating: /content/dataset/dataset/dataset/Wilfred_Enrique_Ritsuka_Estole.jpg
#   inflating: /content/dataset/dataset/dataset/Wilfrid_Kijima.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelm_Bach.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelm_Casper.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelm_Ehrenburg.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelm_Hahn.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelm_Molders.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelm_Schultz.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelm_van_Astrea.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelm_von_Klopstock.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelm_von_Littenheim.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelmina_Braunschweig_Ingenohl_Friedeburg.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelmina_Carmel.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhelmina_Vandom.jpg
#   inflating: /content/dataset/dataset/dataset/Wilhuff_Tarkin.jpg
#   inflating: /content/dataset/dataset/dataset/Wilibald_Koenig.jpg
#   inflating: /content/dataset/dataset/dataset/Will_A_Zeppeli.jpg
#   inflating: /content/dataset/dataset/dataset/Will_B_Good.jpg
#   inflating: /content/dataset/dataset/dataset/Will_Burrows.jpg
#   inflating: /content/dataset/dataset/dataset/Will_Cudeta.jpg
#   inflating: /content/dataset/dataset/dataset/Will_Game.jpg
#   inflating: /content/dataset/dataset/dataset/Will_Raynard.jpg
#   inflating: /content/dataset/dataset/dataset/Willard_Ackroyd.jpg
#   inflating: /content/dataset/dataset/dataset/Willard_Evanstine.jpg
#   inflating: /content/dataset/dataset/dataset/Willard_H_Wright.jpg
#   inflating: /content/dataset/dataset/dataset/Willem_Kmetsch.jpg
#   inflating: /content/dataset/dataset/dataset/William_Adams.jpg
#   inflating: /content/dataset/dataset/dataset/William_Albert_Adley.jpg
#   inflating: /content/dataset/dataset/dataset/William_B_Baxter.jpg
#   inflating: /content/dataset/dataset/dataset/William_Buxton.jpg
#   inflating: /content/dataset/dataset/dataset/William_Cecil.jpg
#   inflating: /content/dataset/dataset/dataset/William_Collins.jpg
#   inflating: /content/dataset/dataset/dataset/William_Davis.jpg
#   inflating: /content/dataset/dataset/dataset/William_Douglas_Drake.jpg
#   inflating: /content/dataset/dataset/dataset/William_G_Maryblood.jpg
#   inflating: /content/dataset/dataset/dataset/William_Gilbert.jpg
#   inflating: /content/dataset/dataset/dataset/William_Hafner.jpg
#   inflating: /content/dataset/dataset/dataset/William_James_Moriarty.jpg
#   inflating: /content/dataset/dataset/dataset/William_Jones.jpg
#   inflating: /content/dataset/dataset/dataset/William_Kippard.jpg
#   inflating: /content/dataset/dataset/dataset/William_Macbeth.jpg
#   inflating: /content/dataset/dataset/dataset/William_Massachusetts.jpg
#   inflating: /content/dataset/dataset/dataset/William_Matheson.jpg
#   inflating: /content/dataset/dataset/dataset/William_Minerva.jpg
#   inflating: /content/dataset/dataset/dataset/William_Morris.jpg
#   inflating: /content/dataset/dataset/dataset/William_Morton.jpg
#   inflating: /content/dataset/dataset/dataset/William_Nelson.jpg
#   inflating: /content/dataset/dataset/dataset/William_Orville.jpg
#   inflating: /content/dataset/dataset/dataset/William_Roland.jpg
#   inflating: /content/dataset/dataset/dataset/William_Satou.jpg
#   inflating: /content/dataset/dataset/dataset/William_Shin.jpg
#   inflating: /content/dataset/dataset/dataset/William_Twining.jpg
#   inflating: /content/dataset/dataset/dataset/William_Vangeance.jpg
#   inflating: /content/dataset/dataset/dataset/William_Walter_Wordsworth.jpg
#   inflating: /content/dataset/dataset/dataset/William_Will_Woo.jpg
#   inflating: /content/dataset/dataset/dataset/William_Wizard.jpg
#   inflating: /content/dataset/dataset/dataset/William_Wynn_Westcott.jpg
#   inflating: /content/dataset/dataset/dataset/Williams.jpg
#   inflating: /content/dataset/dataset/dataset/Williams_Gin.jpg
#   inflating: /content/dataset/dataset/dataset/Willian_Otto.jpg
#   inflating: /content/dataset/dataset/dataset/Willibald_Joachim_von_Merkatz.jpg
#   inflating: /content/dataset/dataset/dataset/Willis_Fujisaki.jpg
#   inflating: /content/dataset/dataset/dataset/Wills_Pelham_Codrington.jpg
#   inflating: /content/dataset/dataset/dataset/Willy_Fog.jpg
#   inflating: /content/dataset/dataset/dataset/Willy_Tybur.jpg
#   inflating: /content/dataset/dataset/dataset/Wilma_Bishop.jpg
#   inflating: /content/dataset/dataset/dataset/Wilma_Etol_von_Asgahan.jpg
#   inflating: /content/dataset/dataset/dataset/Wilmit_Zenam.jpg
#   inflating: /content/dataset/dataset/dataset/Wilna_Janisty.jpg
#   inflating: /content/dataset/dataset/dataset/Wilson_Phillips.jpg
#   inflating: /content/dataset/dataset/dataset/Wily_Glardle.jpg
#   inflating: /content/dataset/dataset/dataset/Wim_Knaup.jpg
#   inflating: /content/dataset/dataset/dataset/Wind.jpg
#   inflating: /content/dataset/dataset/dataset/Windt_Delyus.jpg
#   inflating: /content/dataset/dataset/dataset/Windy_Faster.jpg
#   inflating: /content/dataset/dataset/dataset/Windymay_Aoi.jpg
#   inflating: /content/dataset/dataset/dataset/Winia_Chester.jpg
#   inflating: /content/dataset/dataset/dataset/Winkaa_Jio.jpg
#   inflating: /content/dataset/dataset/dataset/Winkeny_Bizee.jpg
#   inflating: /content/dataset/dataset/dataset/Winnie_the_Pooh.jpg
#   inflating: /content/dataset/dataset/dataset/Winry_Rockbell.jpg
#   inflating: /content/dataset/dataset/dataset/Winston_Churchill.jpg
#   inflating: /content/dataset/dataset/dataset/Winston_Geybridge.jpg
#   inflating: /content/dataset/dataset/dataset/Winston_Zeddemore.jpg
#   inflating: /content/dataset/dataset/dataset/Winter_Woods.jpg
#   inflating: /content/dataset/dataset/dataset/Wired_Beck.jpg
#   inflating: /content/dataset/dataset/dataset/Wiro_Charlotte.jpg
#   inflating: /content/dataset/dataset/dataset/Wirth_Mdl.jpg
#   inflating: /content/dataset/dataset/dataset/Wise_Yuri.jpg
#   inflating: /content/dataset/dataset/dataset/Witch_Regret.jpg
#   inflating: /content/dataset/dataset/dataset/Wizer_Freion.jpg
#   inflating: /content/dataset/dataset/dataset/Wo_Kyuu_Kuubo.jpg
#   inflating: /content/dataset/dataset/dataset/Wodan_Ymir.jpg
#   inflating: /content/dataset/dataset/dataset/Wol_Mae.jpg
#   inflating: /content/dataset/dataset/dataset/Wolf_Chief.jpg
#   inflating: /content/dataset/dataset/dataset/Wolf_Erikmeyer.jpg
#   inflating: /content/dataset/dataset/dataset/Wolf_Frakken.jpg
#   inflating: /content/dataset/dataset/dataset/Wolf_Hawkfield.jpg
#   inflating: /content/dataset/dataset/dataset/Wolf_Kanagushi.jpg
#   inflating: /content/dataset/dataset/dataset/Wolf_Redfield.jpg
#   inflating: /content/dataset/dataset/dataset/Wolf_Sanjuan.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_Amadeus_Mozart.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_Baumann.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_Grimmer.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_Krauser.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_Mittermeyer.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_Pierce.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_Regendorf.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_Schreiber.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_Wall.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_Woerns.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgang_von_Kraftman.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfgangina_Lalla_Getto.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfram.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfram_Gelzer.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfram_von_Bielefeld.jpg
#   inflating: /content/dataset/dataset/dataset/Wolfran_Row.jpg
#   inflating: /content/dataset/dataset/dataset/Woll_Dolnard.jpg
#   inflating: /content/dataset/dataset/dataset/Wolx_Hound.jpg
#   inflating: /content/dataset/dataset/dataset/Won_Jae_Hyun.jpg
#   inflating: /content/dataset/dataset/dataset/Won_Jinon.jpg
#   inflating: /content/dataset/dataset/dataset/Won_Jun_Kang.jpg
#   inflating: /content/dataset/dataset/dataset/Won_Kim.jpg
#   inflating: /content/dataset/dataset/dataset/Won_Sul_Rang.jpg
#   inflating: /content/dataset/dataset/dataset/Won_Woo.jpg
#   inflating: /content/dataset/dataset/dataset/Wonderweiss_Margela.jpg
#   inflating: /content/dataset/dataset/dataset/Wong_Kastrova.jpg
#   inflating: /content/dataset/dataset/dataset/Wong_Yunfat.jpg
#   inflating: /content/dataset/dataset/dataset/Woo_Ik_Han.jpg
#   inflating: /content/dataset/dataset/dataset/Woo_Jin.jpg
#   inflating: /content/dataset/dataset/dataset/Woo_Jin_Kwak.jpg
#   inflating: /content/dataset/dataset/dataset/Woodrow_Kelvin.jpg
#   inflating: /content/dataset/dataset/dataset/Woodstock_W.jpg
# ...
#   inflating: /content/dataset/dataset/dataset/Zain_Hayles.jpg
#   inflating: /content/dataset/dataset/dataset/Zakki_Bronco.jpg
#   inflating: /content/dataset/dataset/dataset/Zako_Red.jpg
#   inflating: /content/dataset/dataset/dataset/Zakot_Dattonel.jpg
#   inflating: /content/dataset/dataset/dataset/Zaku_Abumi.jpg
#   inflating: /content/dataset/dataset/dataset/Zakura_Shidnote.jpg
#   inflating: /content/dataset/dataset/dataset/Zakuro_Fujiwara.jpg
#   inflating: /content/dataset/dataset/dataset/Zakuro_Kurumaki.jpg
#   inflating: /content/dataset/dataset/dataset/Zakuro_Mitsukai.jpg
#   inflating: /content/dataset/dataset/dataset/Zakuro_Oshigiri.jpg
#   inflating: /content/dataset/dataset/dataset/Zakuro_Otonashi.jpg
#   inflating: /content/dataset/dataset/dataset/Zakuro_Takashima.jpg
#   inflating: /content/dataset/dataset/dataset/Zakuro_Zashikiwarashi.jpg
#   inflating: /content/dataset/dataset/dataset/Zalbaag_Beoulve.jpg
#   inflating: /content/dataset/dataset/dataset/Zama__Kosuke_.jpg
#   inflating: /content/dataset/dataset/dataset/Zan_Kishinami.jpg
#   inflating: /content/dataset/dataset/dataset/Zan_Murayama.jpg
#   inflating: /content/dataset/dataset/dataset/Zan_Ruu.jpg
#   inflating: /content/dataset/dataset/dataset/Zanac_Varleon_Igana_Ryle_Vaiself.jpg
#   inflating: /content/dataset/dataset/dataset/Zanak_Zenfield.jpg
#   inflating: /content/dataset/dataset/dataset/Zanald_Beihart.jpg
#   inflating: /content/dataset/dataset/dataset/Zanark_Avalonic.jpg
#   inflating: /content/dataset/dataset/dataset/Zang_Ching_Hang.jpg
#   inflating: /content/dataset/dataset/dataset/Zange_Natsume.jpg
#   inflating: /content/dataset/dataset/dataset/Zank_Rowan.jpg
#   inflating: /content/dataset/dataset/dataset/Zanka_Kinoshita.jpg
#   inflating: /content/dataset/dataset/dataset/Zanki_Kiguchi.jpg
#   inflating: /content/dataset/dataset/dataset/Zanoba_Shirone.jpg
#   inflating: /content/dataset/dataset/dataset/Zanshiro_Gondou.jpg
#   inflating: /content/dataset/dataset/dataset/Zantetsu_Tsurugi.jpg
#   inflating: /content/dataset/dataset/dataset/Zanya_Kisaragi.jpg
#   inflating: /content/dataset/dataset/dataset/Zapiero_Muttaca.jpg
#   inflating: /content/dataset/dataset/dataset/Zapp_Renfro.jpg
#   inflating: /content/dataset/dataset/dataset/Zappa_Shimoi.jpg
#   inflating: /content/dataset/dataset/dataset/Zapper_Zaku.jpg
#   inflating: /content/dataset/dataset/dataset/Zara_Ideale.jpg
#   inflating: /content/dataset/dataset/dataset/Zarado_Shisupuri.jpg
#   inflating: /content/dataset/dataset/dataset/Zarik_Kajiwara.jpg
#   inflating: /content/dataset/dataset/dataset/Zarlisch_Tytania.jpg
#   inflating: /content/dataset/dataset/dataset/Zaruyoshi_Yakushiji.jpg
#   inflating: /content/dataset/dataset/dataset/Zaryusu_Shasha.jpg
#   inflating: /content/dataset/dataset/dataset/Zash_Caine.jpg
#   inflating: /content/dataset/dataset/dataset/Zatoh_Rondohoon.jpg
#   inflating: /content/dataset/dataset/dataset/Zayeed_Winner.jpg
#   inflating: /content/dataset/dataset/dataset/Zazie_Rainyday.jpg
#   inflating: /content/dataset/dataset/dataset/Zazie_The_Darkness.jpg
#   inflating: /content/dataset/dataset/dataset/Zazie_Winters.jpg
#   inflating: /content/dataset/dataset/dataset/Zazie_the_Beast.jpg
#   inflating: /content/dataset/dataset/dataset/Zechs_Doltrake.jpg
#   inflating: /content/dataset/dataset/dataset/Zechs_Marquise.jpg
#   inflating: /content/dataset/dataset/dataset/Zed_Gein.jpg
#   inflating: /content/dataset/dataset/dataset/Zed_OBrien.jpg
#   inflating: /content/dataset/dataset/dataset/Zedong_Mao.jpg
#   inflating: /content/dataset/dataset/dataset/Zeed_Toven.jpg
#   inflating: /content/dataset/dataset/dataset/Zegendo.jpg
#   inflating: /content/dataset/dataset/dataset/Zeheart_Galette.jpg
#   inflating: /content/dataset/dataset/dataset/Zekai_Zhou.jpg
#   inflating: /content/dataset/dataset/dataset/Zeke_Bana.jpg
#   inflating: /content/dataset/dataset/dataset/Zeke_OBrien.jpg
#   inflating: /content/dataset/dataset/dataset/Zekua_Melon.jpg
#   inflating: /content/dataset/dataset/dataset/Zelfa_Kreuz.jpg
#   inflating: /content/dataset/dataset/dataset/Zelgadis_Graywords.jpg
#   inflating: /content/dataset/dataset/dataset/Zelia_Bastos.jpg
#   inflating: /content/dataset/dataset/dataset/Zelman_Clock.jpg
#   inflating: /content/dataset/dataset/dataset/Zelos_Draghart.jpg
#   inflating: /content/dataset/dataset/dataset/Zelos_Wilder.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Fudou.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Inubashiri.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Joumori.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Kamioka.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Kirishima.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Kusanagi.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Makunouchi.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Minedera.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Nagiomi.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Nakajou.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Takazuchiya.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Uruma.jpg
#   inflating: /content/dataset/dataset/dataset/Zen_Wistalia.jpg
#   inflating: /content/dataset/dataset/dataset/Zen__Seizaki.jpg
#   inflating: /content/dataset/dataset/dataset/Zena_Hoshigami.jpg
#   inflating: /content/dataset/dataset/dataset/Zena_Marientail.jpg
#   inflating: /content/dataset/dataset/dataset/Zenberu_Gugu.jpg
#   inflating: /content/dataset/dataset/dataset/Zende_Neubauten.jpg
#   inflating: /content/dataset/dataset/dataset/Zenichi_Bunkyou.jpg
#   inflating: /content/dataset/dataset/dataset/Zenichi_Innami.jpg
#   inflating: /content/dataset/dataset/dataset/Zenichirou_Shii.jpg
#   inflating: /content/dataset/dataset/dataset/Zenith_Greyrat.jpg
#   inflating: /content/dataset/dataset/dataset/Zenitsu_Agatsuma.jpg
#   inflating: /content/dataset/dataset/dataset/Zenji_Banba.jpg
#   inflating: /content/dataset/dataset/dataset/Zenji_Gion.jpg
#   inflating: /content/dataset/dataset/dataset/Zenji_Kagitani.jpg
#   inflating: /content/dataset/dataset/dataset/Zenji_Marui.jpg
#   inflating: /content/dataset/dataset/dataset/Zenji_Oyamada.jpg
#   inflating: /content/dataset/dataset/dataset/Zenji_Saiga.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjirou_Ikeda.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjirou_Kasai.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjirou_Kogure.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjirou_Shibukawa.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjirou_Tsurugi.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjirou_Yamaguchi.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjirou_Yamai.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjirou_Yamamoto.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjuuro_Saotome.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjuurou_Okuma.jpg
#   inflating: /content/dataset/dataset/dataset/Zenjuurou_Oofujiwara.jpg
#   inflating: /content/dataset/dataset/dataset/Zenkichi_Fujita.jpg
#   inflating: /content/dataset/dataset/dataset/Zenkichi_Hitoyoshi.jpg
#   inflating: /content/dataset/dataset/dataset/Zenkichi_Oooka.jpg
#   inflating: /content/dataset/dataset/dataset/Zenkichi_Otomi.jpg
#   inflating: /content/dataset/dataset/dataset/Zenko_Fujiwara.jpg
#   inflating: /content/dataset/dataset/dataset/Zenkurou_Kurogane.jpg
#   inflating: /content/dataset/dataset/dataset/Zenmai_Makashima.jpg
#   inflating: /content/dataset/dataset/dataset/Zenmaru_Ichinose.jpg
#   inflating: /content/dataset/dataset/dataset/Zenmei_Muroto.jpg
#   inflating: /content/dataset/dataset/dataset/Zenna_Zabi.jpg
#   inflating: /content/dataset/dataset/dataset/Zennosuke_Kurumadani.jpg
#   inflating: /content/dataset/dataset/dataset/Zeno_Mozesty.jpg
#   inflating: /content/dataset/dataset/dataset/Zeno_Zoldyck.jpg
#   inflating: /content/dataset/dataset/dataset/Zenobia_L_Edgware.jpg
#   inflating: /content/dataset/dataset/dataset/Zenon_Houjou.jpg
#   inflating: /content/dataset/dataset/dataset/Zenshichi__Yoshikawa.jpg
#   inflating: /content/dataset/dataset/dataset/Zensuke_Ookouchi.jpg
#   inflating: /content/dataset/dataset/dataset/Zenzaburo_Mitsukoshi.jpg
#   inflating: /content/dataset/dataset/dataset/Zenzo_Kadoma.jpg
#   inflating: /content/dataset/dataset/dataset/Zenzo_Saeki.jpg
#   inflating: /content/dataset/dataset/dataset/Zenzou_Hattori.jpg
#   inflating: /content/dataset/dataset/dataset/Zenzou_Inukai.jpg
#   inflating: /content/dataset/dataset/dataset/Zenzou_Kotoura.jpg
#   inflating: /content/dataset/dataset/dataset/Zenzou_Kuroki.jpg
#   inflating: /content/dataset/dataset/dataset/Zeo_Abyss.jpg
#   inflating: /content/dataset/dataset/dataset/Zeo_Zagart.jpg
#   inflating: /content/dataset/dataset/dataset/Zeon_Bell.jpg
#   inflating: /content/dataset/dataset/dataset/Zeon_Zum_Deikun.jpg
#   inflating: /content/dataset/dataset/dataset/Zeoticus_Gremory.jpg
#   inflating: /content/dataset/dataset/dataset/Zephiel_Ietsura.jpg
#   inflating: /content/dataset/dataset/dataset/Zephyrdor_Glasya_Labolas.jpg
#   inflating: /content/dataset/dataset/dataset/Zera_Gins.jpg
#   inflating: /content/dataset/dataset/dataset/Zero_Kirisame.jpg
#   inflating: /content/dataset/dataset/dataset/Zero_Kiryuu.jpg
#   inflating: /content/dataset/dataset/dataset/Zero_Kurogane.jpg
#   inflating: /content/dataset/dataset/dataset/Zero_Manai.jpg
#   inflating: /content/dataset/dataset/dataset/Zero_Shinagawa.jpg
#   inflating: /content/dataset/dataset/dataset/Zero_Tokyo.jpg
#   inflating: /content/dataset/dataset/dataset/Zero_Ukai.jpg
#   inflating: /content/dataset/dataset/dataset/Zero_Yagami.jpg
#   inflating: /content/dataset/dataset/dataset/Zero_Zephyrum.jpg
#   inflating: /content/dataset/dataset/dataset/Zerodaimu_Kyupura_Pa_Azaraku_Vairu_Rua_Darugo.jpg
#   inflating: /content/dataset/dataset/dataset/Zeroemon_Kiryuin_Sakon.jpg
#   inflating: /content/dataset/dataset/dataset/Zeruel_Tenma_White.jpg
#   inflating: /content/dataset/dataset/dataset/Zesshi_Zetsumei.jpg
#   inflating: /content/dataset/dataset/dataset/Zessica_Wong.jpg
#   inflating: /content/dataset/dataset/dataset/Zest_Bernard.jpg
#   inflating: /content/dataset/dataset/dataset/Zest_De_Noir.jpg
#   inflating: /content/dataset/dataset/dataset/Zest_Grangaitz.jpg
#   inflating: /content/dataset/dataset/dataset/Zetsu_Daidan.jpg
#   inflating: /content/dataset/dataset/dataset/Zetsubi_Hazama.jpg
#   inflating: /content/dataset/dataset/dataset/Zetsuro_Waltzer.jpg
#   inflating: /content/dataset/dataset/dataset/Zetto_Ichimura.jpg
#   inflating: /content/dataset/dataset/dataset/Zeus_Keraunos.jpg
#   inflating: /content/dataset/dataset/dataset/Zeus_Reisenbach.jpg
#   inflating: /content/dataset/dataset/dataset/Zeus_Tetsuya.jpg
#   inflating: /content/dataset/dataset/dataset/Zhang.jpg
#   inflating: /content/dataset/dataset/dataset/Zhang_Lei_Hui_Guo_Rou.jpg
#   inflating: /content/dataset/dataset/dataset/Zhang_Qian.jpg
#   inflating: /content/dataset/dataset/dataset/Zhang__Shao_Zu.jpg
#   inflating: /content/dataset/dataset/dataset/Zhangxuan_Shenlong.jpg
#   inflating: /content/dataset/dataset/dataset/Zhao_Mong_Cheng.jpg
#   inflating: /content/dataset/dataset/dataset/Zhao_Pu.jpg
#   inflating: /content/dataset/dataset/dataset/Zhao_Yin.jpg
#   inflating: /content/dataset/dataset/dataset/Zhao_Zhao_Ye.jpg
#   inflating: /content/dataset/dataset/dataset/Zhen_Baili.jpg
#   inflating: /content/dataset/dataset/dataset/Zheng_Ying.jpg
#   inflating: /content/dataset/dataset/dataset/Zhengliang_Jia.jpg
#   inflating: /content/dataset/dataset/dataset/Zhengsheng_Gao.jpg
#   inflating: /content/dataset/dataset/dataset/Zhenzhen_Bai.jpg
#   inflating: /content/dataset/dataset/dataset/Zhetian_Yao.jpg
#   inflating: /content/dataset/dataset/dataset/ZhiGao_Ji.jpg
#   inflating: /content/dataset/dataset/dataset/Zhijun_Wei.jpg
#   inflating: /content/dataset/dataset/dataset/Zhilan_Bao.jpg
#   inflating: /content/dataset/dataset/dataset/Zhinzhee_Bekka_Arr_Thied.jpg
#   inflating: /content/dataset/dataset/dataset/Zhiqiang_Mao.jpg
#   inflating: /content/dataset/dataset/dataset/Zhiyang_He.jpg
#   inflating: /content/dataset/dataset/dataset/Zhon_Han_Chen.jpg
#   inflating: /content/dataset/dataset/dataset/Zhong_Tian.jpg
#   inflating: /content/dataset/dataset/dataset/Zhonglu_Wu.jpg
#   inflating: /content/dataset/dataset/dataset/Zhongmian_Yue.jpg
#   inflating: /content/dataset/dataset/dataset/Zhou_Zi.jpg
#   inflating: /content/dataset/dataset/dataset/Zhu_Zhuqing.jpg
#   inflating: /content/dataset/dataset/dataset/Zhuang_Wei.jpg
#   inflating: /content/dataset/dataset/dataset/Zhuang_Zhao.jpg
#   inflating: /content/dataset/dataset/dataset/Zhui_Ri.jpg
#   inflating: /content/dataset/dataset/dataset/Zhuliu_Wen.jpg
#   inflating: /content/dataset/dataset/dataset/Zhuo_Dong.jpg
#   inflating: /content/dataset/dataset/dataset/Zi_Dian.jpg
#   inflating: /content/dataset/dataset/dataset/Zian_Manas.jpg
#   inflating: /content/dataset/dataset/dataset/Zidane_Tribal.jpg
#   inflating: /content/dataset/dataset/dataset/Zilch_Kanoa.jpg
#   inflating: /content/dataset/dataset/dataset/Zili_Tang.jpg
#   inflating: /content/dataset/dataset/dataset/Zilong_Zhao.jpg
#   inflating: /content/dataset/dataset/dataset/Zimo_Yu.jpg
#   inflating: /content/dataset/dataset/dataset/Zin_Kusanagi.jpg
#   inflating: /content/dataset/dataset/dataset/Zion_Thenardier.jpg
#   inflating: /content/dataset/dataset/dataset/Zita_Brusasco.jpg
#   inflating: /content/dataset/dataset/dataset/Zitong_Xia.jpg
#   inflating: /content/dataset/dataset/dataset/Zixuan_Chen.jpg
#   inflating: /content/dataset/dataset/dataset/Zixuan_Jin.jpg
#   inflating: /content/dataset/dataset/dataset/Ziyu_Pan.jpg
#   inflating: /content/dataset/dataset/dataset/Ziyuan_Mo.jpg
#   inflating: /content/dataset/dataset/dataset/Ziyuan_Yu.jpg
#   inflating: /content/dataset/dataset/dataset/Zodd_Nosferatu.jpg
#   inflating: /content/dataset/dataset/dataset/Zoe_Vasconcelos.jpg
#   inflating: /content/dataset/dataset/dataset/Zoellick_Helm.jpg
#   inflating: /content/dataset/dataset/dataset/Zofuu_Karama.jpg
#   inflating: /content/dataset/dataset/dataset/Zol_Balfaltin.jpg
#   inflating: /content/dataset/dataset/dataset/Zola_Axberg.jpg
#   inflating: /content/dataset/dataset/dataset/Zoltan_Akkanen.jpg
#   inflating: /content/dataset/dataset/dataset/Zombie_Yoonha.jpg
#   inflating: /content/dataset/dataset/dataset/Zong_Ming_Chen.jpg
#   inflating: /content/dataset/dataset/dataset/Zongheng_Tianxia.jpg
#   inflating: /content/dataset/dataset/dataset/Zora_Ideale.jpg
#   inflating: /content/dataset/dataset/dataset/Zorin_Blitz.jpg
#   inflating: /content/dataset/dataset/dataset/Zoro_Roronoa.jpg
#   inflating: /content/dataset/dataset/dataset/Zorya_Gagarik.jpg
#   inflating: /content/dataset/dataset/dataset/Zorzal_El_Caesar.jpg
#   inflating: /content/dataset/dataset/dataset/Zouichi_Kanoe.jpg
#   inflating: /content/dataset/dataset/dataset/Zouken_Matou.jpg
#   inflating: /content/dataset/dataset/dataset/Zouroku_Kashimura.jpg
#   inflating: /content/dataset/dataset/dataset/Zoushi_Kanai.jpg
#   inflating: /content/dataset/dataset/dataset/Zu_Mei_Chang.jpg
#   inflating: /content/dataset/dataset/dataset/Zuccotto_Charlotte.jpg
#   inflating: /content/dataset/dataset/dataset/Zuchini_Nicchini.jpg
#   inflating: /content/dataset/dataset/dataset/Zuizo.jpg
#   inflating: /content/dataset/dataset/dataset/Zunko_Touhoku.jpg
#   inflating: /content/dataset/dataset/dataset/Zusho_no_Suke_Himekawa.jpg
#   inflating: /content/dataset/dataset/dataset/de_Signore.jpg
#   inflating: /content/dataset/dataset/dataset/dosa_Meoteol.jpg
#   inflating: /content/dataset/dataset/dataset/ngela_Salas_Larrazbal.jpg
#   inflating: /content/dataset/dataset/dataset/ponine_Thnardier.jpg
#   inflating: /content/dataset/dataset/dataset/ufcoque_Penteano.jpg
#   inflating: /content/dataset/final_names.csv

# %% [markdown]
# ## Preprocessing Data

# %%
BATCH_SIZE = 128
IM_SHAPE = (64, 64, 3)
LR = 2e-4
LATENT_DIM = 100 # max hidden features captured

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/dataset/dataset/dataset', label_mode = None, image_size = (IM_SHAPE[0], IM_SHAPE[1]), batch_size = BATCH_SIZE
)
# Out:
# Found 58085 files belonging to 1 classes.

# %%
dataset
# Out:
# <_BatchDataset element_spec=TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None)>

# %% [markdown]
# ### Preprocess Function

# %%
def preprocess(image):
  return tf.cast(image, tf.float32) / 127.5 - 1.0 # 127.5 is basically mean-centering then after that we obtain value that we  subtract from 1 which makes the value fall within -1 to 1 is used by activation functions
  # this method is used for GAN's normally for image classification value between 0 and 1 is used which image/255.0
  # the model's architecture and choice of activation functions play a big role in deciding the preprocessing methods, but softmax and sigmoid are more based on 0, 1 value so for them image/255.0 is a better approach

# %% [markdown]
# ### Batching

# %%
train_dataset= (
    dataset
    .map(preprocess)
    .unbatch() # unbatching to shuffle the datapoints and drop remainder
    .shuffle(buffer_size = 1024, reshuffle_each_iteration = True)
    .batch(BATCH_SIZE, drop_remainder = True) # dropping unmatched bacthes
    .prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# ### Visualization of Dataset

# %%
for data in train_dataset.take(1):
  print(data.shape)
# Out:
# (128, 64, 64, 3)

# %%
plt.figure(figsize = (6, 6))
k = 0
n = 4
for i in range(n):
  ax = plt.subplot(2, 2, k + 1)
  plt.imshow((data[i] + 1) / 2) # just for visualizing since our data was prepocessed to fall in range between -1, 1 the images werent clear thats why converted them to fall in range 0, 1
  # by adding 1 and then getting the mean d[i] + 1 / 2
  plt.axis('off')
  k += 1

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Generator Model

# %%
generator = tf.keras.Sequential([
    Input(shape=(LATENT_DIM)),
    Dense(4 * 4 * LATENT_DIM),
    Reshape((4, 4, LATENT_DIM)),

    Conv2DTranspose(512, kernel_size = 4, strides = 2, padding = 'same'),  # kernel size should be divisble by strides for quality of the outputs
    BatchNormalization(),
    LeakyReLU(0.2), # alpha set to 0.2 which is the scale down value, suppose the gradient is -0.2 then the output would gradient * alpha which is -0.2 * 0.2 which -0.04
    # it reduces by a factor of 0.2

    Conv2DTranspose(256, kernel_size = 4, strides = 2, padding = 'same'),
    BatchNormalization(),
    LeakyReLU(0.2),


    Conv2DTranspose(128, kernel_size = 4, strides = 2, padding = 'same'),
    BatchNormalization(),
    LeakyReLU(0.2),

    Conv2DTranspose(3, kernel_size = 4, strides = 2, padding = 'same', activation = tf.keras.activations.tanh), # maps values between -1 and 1


], name = 'generator')

# %% [markdown]
# Slowly and steadily Upsampling image

# %%
generator.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1600)              161600
#
#  reshape (Reshape)           (None, 4, 4, 100)         0
#
#  conv2d_transpose (Conv2DTr  (None, 8, 8, 512)         819712
#  anspose)
#
#  batch_normalization (Batch  (None, 8, 8, 512)         2048
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 8, 8, 512)         0
#
#  conv2d_transpose_1 (Conv2D  (None, 16, 16, 256)       2097408
#  Transpose)
#
#  batch_normalization_1 (Bat  (None, 16, 16, 256)       1024
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  conv2d_transpose_2 (Conv2D  (None, 32, 32, 128)       524416
#  Transpose)
#
#  batch_normalization_2 (Bat  (None, 32, 32, 128)       512
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  conv2d_transpose_3 (Conv2D  (None, 64, 64, 3)         6147
#  Transpose)
#
# =================================================================
# Total params: 3612867 (13.78 MB)
# Trainable params: 3611075 (13.78 MB)
# Non-trainable params: 1792 (7.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## Discriminator Model

# %%
discriminator = tf.keras.Sequential([
    Input(shape=(IM_SHAPE[0], IM_SHAPE[1], 3)),

    Conv2D(64, kernel_size = 4, strides = 2, padding = 'same'),  # kernel size should be divisble by strides for quality of the outputs
    LeakyReLU(0.2),

    Conv2D(128, kernel_size = 4, strides = 2, padding = 'same'),
    BatchNormalization(),
    LeakyReLU(0.2),


    Conv2D(256, kernel_size = 4, strides = 2, padding = 'same'),
    BatchNormalization(),
    LeakyReLU(0.2),

    Conv2D(1, kernel_size = 4, strides = 2, padding = 'same'),

    Flatten(),

    Dense(1, activation = 'sigmoid') # value is in between 0 and 1


], name = 'discriminator')

# %% [markdown]
# Normally if there is no activation functions mentioned then there is no activation taking place and output is passed to the next layer without any non-linear transformations, f(x)=x.

# %%
discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        3136
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 32, 32, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 128)       131200
#
#  batch_normalization_3 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 256)         524544
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 8, 8, 256)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 1)           4097
#
#  flatten (Flatten)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 664530 (2.53 MB)
# Trainable params: 663762 (2.53 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## Override Train Step for Customization

# %%
class GAN1(tf.keras.Model):
  def __init__(self,discriminator,generator):
    super(GAN1,self).__init__()
    self.discriminator=discriminator
    self.generator=generator

  """ Models Compilation """
  def compile(self,d_optimizer,g_optimizer,loss_fn):
    super(GAN1,self).compile()
    self.d_optimizer=d_optimizer
    self.g_optimizer=g_optimizer
    self.loss_fn=loss_fn # BCE(Binary Cross Entropy)
    self.d_loss_metric=tf.keras.metrics.Mean(name='d_loss')
    self.g_loss_metric=tf.keras.metrics.Mean(name='g_loss')

  @property
  def metrics(self):
    return [self.d_loss_metric,self.g_loss_metric]

  def train_step(self,real_images):
    batch_size=tf.shape(real_images)[0]

    """ Discriminator """
    random_noise=tf.random.normal(shape=(batch_size,LATENT_DIM))
    fake_images=self.generator(random_noise)

    real_labels=tf.ones((batch_size,1))+0.25*tf.random.uniform((batch_size,1),minval=-1,maxval=1)
    fake_labels=tf.zeros((batch_size,1))+0.25*tf.random.uniform((batch_size,1),)
     # random labels are assigned from thet get go for smooth training(label smoothing)
    with tf.GradientTape() as recorder:
      real_predictions=self.discriminator(real_images)
      d_loss_real=self.loss_fn(real_labels,real_predictions)
      # comparing the predictions to higher probability or 1

      fake_predictions=self.discriminator(fake_images)
      d_loss_fake=self.loss_fn(fake_labels,fake_predictions)
      # comparing the predictions to lower probability or 0

      d_loss=d_loss_real+d_loss_fake
      # total discriminator loss

    partial_derivatives = recorder.gradient(d_loss,self.discriminator.trainable_weights)
    self.d_optimizer.apply_gradients(zip(partial_derivatives, self.discriminator.trainable_weights))
    # updating weights and biases through back propogation with the help of gradient tape of Discriminator
    # Discriminator tries to reduce loss in the Ascent direction

    """ Generator """
    random_noise=tf.random.normal(shape=(batch_size,LATENT_DIM))
    flipped_fake_labels=tf.ones((batch_size,1)) # like the one in paper for the kickstart

    with tf.GradientTape() as recorder:

      fake_predictions=self.discriminator(self.generator(random_noise))
      g_loss=self.loss_fn(flipped_fake_labels,fake_predictions)
      # only on loss for g because its making only fake images

    partial_derivatives = recorder.gradient(g_loss,self.generator.trainable_weights)
    self.g_optimizer.apply_gradients(zip(partial_derivatives, self.generator.trainable_weights))
    # updating weights and biases through back propogation with the help of gradient tape of Generator
    # Discriminator tries to reduce loss in the Descent direction for Higher quality of Fake images

    self.d_loss_metric.update_state(d_loss)
    self.g_loss_metric.update_state(g_loss)
    # loss update

    return {'d_loss':self.d_loss_metric.result(),
            'g_loss':self.g_loss_metric.result()}

# %% [markdown]
# Gradient Tape is a key component of backpropagation, which is the process used to train neural networks by iteratively adjusting model parameters to minimize the loss function. In essence, Gradient Tape plays a vital role in both forward and backward passes, making it possible to perform automatic differentiation and train deep learning models effectively.

# %% [markdown]
# # Callbacks

# %% [markdown]
# ## Checkpoint Callback

# %%
from keras.callbacks import ModelCheckpoint
checkpoint_callback = ModelCheckpoint("//content/drive/MyDrive/Colab Notebooks/DCGAN Model/DCGAN-celebs-v1", save_best_only=True)

# %% [markdown]
# ## Show Image Callback Method

# %%
# !mkdir generated

# %%
class ShowImage(tf.keras.callbacks.Callback):
    def __init__(self, latent_dim=100):
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        n = 6
        k = 0
        out = self.model.generator(tf.random.normal(shape=(36, self.latent_dim)))
        plt.figure(figsize = (16,16))
        for i in range(n):
          for j in range(n):
            ax = plt.subplot(n, n, k+1)
            plt.imshow((out[k] + 1 ) / 2,) # making the output in between 0 and 1 like before
            plt.axis('off')
            k += 1
        plt.savefig("generated/gen_images_epoch_{}.png".format(epoch+1))

# %% [markdown]
# This class helps in debugging by showing what the model is generating after each epoch.

# %% [markdown]
# # Model Compilation and Training

# %%
gan = GAN1(discriminator, generator)

gan.compile(
    d_optimizer = tf.keras.optimizers.Adam(learning_rate = LR, beta_1 = 0.5),
    g_optimizer = tf.keras.optimizers.Adam(learning_rate = LR, beta_1 = 0.5), # thats the nash equillibrium point
    loss_fn = tf.keras.losses.BinaryCrossentropy(),
)

# %%
history = gan.fit(train_dataset, epochs = 30, callbacks = [ShowImage(LATENT_DIM)])
# Out:
# Epoch 1/30
#       6/Unknown - 16s 62ms/step - d_loss: 1.0771 - g_loss: 0.6400
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0210s vs `on_train_batch_end` time: 0.0333s). Check your callbacks.
# 453/453 [==============================] - 43s 59ms/step - d_loss: 0.9348 - g_loss: 1.8875
# Epoch 2/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 1.1122 - g_loss: 1.2888
# Epoch 3/30
# 453/453 [==============================] - 27s 58ms/step - d_loss: 1.1018 - g_loss: 1.2956
# Epoch 4/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 1.0694 - g_loss: 1.3942
# Epoch 5/30
# 453/453 [==============================] - 27s 58ms/step - d_loss: 1.0426 - g_loss: 1.3285
# Epoch 6/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 1.0244 - g_loss: 1.2495
# Epoch 7/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 1.0089 - g_loss: 1.2802
# Epoch 8/30
# 453/453 [==============================] - 27s 58ms/step - d_loss: 0.9927 - g_loss: 1.3186
# Epoch 9/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9682 - g_loss: 1.2831
# Epoch 10/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9778 - g_loss: 1.2635
# Epoch 11/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 1.0111 - g_loss: 1.2227
# Epoch 12/30
# 453/453 [==============================] - 27s 58ms/step - d_loss: 0.9792 - g_loss: 1.1997
# Epoch 13/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 1.0023 - g_loss: 1.2078
# Epoch 14/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9828 - g_loss: 1.1958
# Epoch 15/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9842 - g_loss: 1.2379
# Epoch 16/30
# 453/453 [==============================] - 27s 58ms/step - d_loss: 0.9778 - g_loss: 1.2301
# Epoch 17/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9666 - g_loss: 1.2365
# Epoch 18/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9390 - g_loss: 1.2668
# Epoch 19/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9419 - g_loss: 1.2946
# Epoch 20/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9258 - g_loss: 1.3300
# Epoch 21/30
# 453/453 [==============================] - ETA: 0s - d_loss: 0.9285 - g_loss: 1.3281
# <ipython-input-16-af82e8c7a118>:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize = (16,16))
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9285 - g_loss: 1.3281
# Epoch 22/30
# 453/453 [==============================] - 27s 59ms/step - d_loss: 0.9078 - g_loss: 1.3673
# Epoch 23/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9063 - g_loss: 1.3770
# Epoch 24/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9186 - g_loss: 1.3817
# Epoch 25/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.8851 - g_loss: 1.3468
# Epoch 26/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.9020 - g_loss: 1.4075
# Epoch 27/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.8984 - g_loss: 1.4138
# Epoch 28/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.8737 - g_loss: 1.4084
# Epoch 29/30
# 453/453 [==============================] - 27s 59ms/step - d_loss: 0.8844 - g_loss: 1.4214
# Epoch 30/30
# 453/453 [==============================] - 26s 57ms/step - d_loss: 0.8582 - g_loss: 1.4495

# %% [markdown]
# # Model loss Visualization

# %%
plt.plot(history.history['d_loss'])
plt.plot(history.history['g_loss'])
plt.title('GAN Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['d_loss', 'g_loss'], loc='upper left')
plt.show()
